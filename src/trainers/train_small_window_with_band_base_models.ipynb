# %%
import src.utils.create_models_util as models_util

FILE_PATH = "../../processed_data/SDHAR/final_processed_data_ALL_DAYS_small_window_with_band.csv"
TARGET_COLUMN = 'activity_user_1'  # We will predict the activity for User 1
WINDOW_SIZE = 60  # How many past time steps to look at (e.g., 60 * 1s = 60 seconds of history)
STEP_SIZE = 30    # How far to slide the window forward each time

# %% [markdown]
# # LSTM

# %%
save_path = "../../models/SDHAR/LSTM_small_window_with_band.keras"

models_util.train_and_save_lstm(FILE_PATH, save_path, TARGET_COLUMN, WINDOW_SIZE, STEP_SIZE)
# Out:
# Loading final processed data...
# Separating data...
# Creating sliding windows (size=60, step=30)...
#   - Windowed X shape: (134935, 60, 47)
#   - Windowed y shape: (134935, 18)
# Splitting data into training and test sets...
#   - Training set size: 107948
#   - Test set size: 26987
# Building the LSTM model...
# C:\Users\jesse\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 64)         │        28,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 18)             │         1,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 62,866 (245.57 KB)
#  Trainable params: 62,866 (245.57 KB)
#  Non-trainable params: 0 (0.00 B)
# Training the model...
# Epoch 1/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 84s 101ms/step - accuracy: 0.6709 - loss: 1.1251 - val_accuracy: 0.6995 - val_loss: 0.9344
# Epoch 2/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 83s 110ms/step - accuracy: 0.6983 - loss: 0.9444 - val_accuracy: 0.6938 - val_loss: 0.9100
# Epoch 3/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 100s 131ms/step - accuracy: 0.7071 - loss: 0.9137 - val_accuracy: 0.7221 - val_loss: 0.8712
# Epoch 4/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 118s 100ms/step - accuracy: 0.7185 - loss: 0.8703 - val_accuracy: 0.7270 - val_loss: 0.8299
# Epoch 5/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 74s 97ms/step - accuracy: 0.7266 - loss: 0.8429 - val_accuracy: 0.7177 - val_loss: 0.8718
# Epoch 6/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 73s 96ms/step - accuracy: 0.7342 - loss: 0.8120 - val_accuracy: 0.7447 - val_loss: 0.7544
# Epoch 7/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 80s 106ms/step - accuracy: 0.7519 - loss: 0.7686 - val_accuracy: 0.7167 - val_loss: 0.9097
# Epoch 8/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 71s 93ms/step - accuracy: 0.7591 - loss: 0.7413 - val_accuracy: 0.7834 - val_loss: 0.6563
# Epoch 9/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 68s 89ms/step - accuracy: 0.7664 - loss: 0.7230 - val_accuracy: 0.7817 - val_loss: 0.6747
# Epoch 10/10
# 760/760 ━━━━━━━━━━━━━━━━━━━━ 68s 89ms/step - accuracy: 0.7770 - loss: 0.6851 - val_accuracy: 0.7852 - val_loss: 0.6460
#
# Evaluating the model on the test set...
#
# Test Accuracy: 79.10%
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.67      0.60       795
#            1       0.41      0.12      0.18       151
#            2       0.61      0.11      0.19       265
#            3       0.67      0.13      0.22        31
#            4       0.00      0.00      0.00        67
#            5       0.58      0.09      0.15      1257
#            6       0.00      0.00      0.00         5
#            7       0.31      0.02      0.05       164
#            8       0.92      0.94      0.93     10467
#            9       0.00      0.00      0.00        35
#           10       0.59      0.19      0.28       343
#           11       0.00      0.00      0.00       322
#           12       0.63      0.73      0.68       168
#           13       0.98      0.94      0.96      8654
#           14       0.00      0.00      0.00         9
#           15       0.41      0.82      0.54      2187
#           16       0.43      0.18      0.25       666
#           17       0.35      0.40      0.37      1401
#
#     accuracy                           0.79     26987
#    macro avg       0.41      0.30      0.30     26987
# weighted avg       0.80      0.79      0.77     26987
# C:\Users\jesse\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\jesse\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\jesse\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Random Forest

# %%
save_path = "../../models/SDHAR/RandomForest_small_window_with_band.joblib"

models_util.train_and_save_rf(FILE_PATH, save_path, TARGET_COLUMN, WINDOW_SIZE, STEP_SIZE)
# Out:
# Loading final processed data...
# Separating Features and Target...
# Creating sliding windows (size=60, step=30)...
#   - Initial windowed X shape: (134935, 60, 47)
# Flattening window data...
#   - Flattened X shape: (134935, 2820)
# Splitting data into training and test sets...
#   - Training set size: 107948
#   - Test set size: 26987
#
# Building and training the Random Forest model...
#
# Evaluating the model on the test set...
#
# Test Accuracy: 98.77%
#
# Classification Report:
#                    precision    recall  f1-score   support
#
# BATHROOM ACTIVITY       0.94      0.95      0.95       795
#            CHORES       0.98      0.91      0.94       151
#              COOK       0.97      0.97      0.97       265
#       DISHWASHING       0.91      0.97      0.94        31
#             DRESS       0.85      0.67      0.75        67
#               EAT       0.96      0.99      0.97      1257
#           LAUNDRY       1.00      0.60      0.75         5
#  MAKE SIMPLE FOOD       0.94      0.80      0.86       164
#          OUT HOME       1.00      1.00      1.00     10467
#               PET       0.73      0.31      0.44        35
#              READ       0.96      0.98      0.97       343
#             RELAX       0.96      0.97      0.97       322
#            SHOWER       0.95      0.98      0.96       168
#             SLEEP       1.00      1.00      1.00      8654
#         TAKE MEDS       0.62      0.89      0.73         9
#          WATCH TV       0.99      0.99      0.99      2187
#              WORK       0.99      0.98      0.98       666
#             OTHER       0.93      0.93      0.93      1401
#
#          accuracy                           0.99     26987
#         macro avg       0.93      0.88      0.89     26987
#      weighted avg       0.99      0.99      0.99     26987

# %% [markdown]
# # Decision Tree

# %%
save_path = "../../models/SDHAR/DecisionTree_small_window_with_band.joblib"

models_util.train_and_save_dt(FILE_PATH, save_path, TARGET_COLUMN, WINDOW_SIZE, STEP_SIZE)
# Out:
# Loading final processed data...
# Separating Features and Target...
# Creating sliding windows (size=60, step=30)...
#   - Initial windowed X shape: (134935, 60, 47)
# Flattening window data...
#   - Flattened X shape: (134935, 2820)
# Splitting data into training and test sets...
#   - Training set size: 107948
#   - Test set size: 26987
# Building and training the Decision Tree model...
#   - Model training complete!
# Evaluating the model on the test set...
#
# Test Accuracy: 97.47%
#
# Classification Report:
#                    precision    recall  f1-score   support
#
# BATHROOM ACTIVITY       0.94      0.93      0.93       795
#            CHORES       0.85      0.82      0.84       151
#              COOK       0.90      0.89      0.89       265
#       DISHWASHING       0.78      0.90      0.84        31
#             DRESS       0.60      0.60      0.60        67
#               EAT       0.93      0.94      0.93      1257
#           LAUNDRY       0.67      0.40      0.50         5
#  MAKE SIMPLE FOOD       0.70      0.74      0.72       164
#          OUT HOME       1.00      1.00      1.00     10467
#               PET       0.51      0.51      0.51        35
#              READ       0.94      0.93      0.94       343
#             RELAX       0.93      0.92      0.93       322
#            SHOWER       0.94      0.96      0.95       168
#             SLEEP       1.00      1.00      1.00      8654
#         TAKE MEDS       0.62      0.89      0.73         9
#          WATCH TV       0.97      0.97      0.97      2187
#              WORK       0.96      0.95      0.96       666
#             OTHER       0.88      0.86      0.87      1401
#
#          accuracy                           0.97     26987
#         macro avg       0.84      0.84      0.84     26987
#      weighted avg       0.97      0.97      0.97     26987
#
# Saving the Decision Tree model...
#   - Model saved successfully!
